# %% [markdown]
# # Example 13 - Train, Val, Test pipeline (different thresholds)
#
# In this notebook, we'll train models for different thresholds, validate models for different thresholds, test models on the selected threshold.

# %% [markdown]
# ## Step 1. Train models on different thresholds
#
# In this step, we'll train models on different thresholds, co-training models with CNN or HC features.

# %%
from train_co_training_CNN import TrainCoTrainingCNN
from train_co_training_HC import TrainCoTrainingHC

# %%
# path
pkl_dir = "pkl/"
train_dir = "npy/train/"

# %%
# parameters
threshold = -66
iou_threshold = 0.5
neg_pos_ratio = 2
unlabel_label_ratio = 1
sel_feats = ['total_water_column', 'depth', 'latitude', 'longitude'] # contextual features
left_feats = ['Sv_18kHz_min', 'Sv_18kHz_p5', 'Sv_18kHz_p25', 'Sv_18kHz_p50', 'Sv_18kHz_p75', 'Sv_18kHz_p95', 'Sv_18kHz_max', 'Sv_18kHz_std', 'Sv_38kHz_min', 'Sv_38kHz_p5', 'Sv_38kHz_p25', 'Sv_38kHz_p50', 'Sv_38kHz_p75', 'Sv_38kHz_p95', 'Sv_38kHz_max', 'Sv_38kHz_std', 'Sv_120kHz_min', 'Sv_120kHz_p5', 'Sv_120kHz_p25', 'Sv_120kHz_p50', 'Sv_120kHz_p75', 'Sv_120kHz_p95', 'Sv_120kHz_max', 'Sv_120kHz_std', 'Sv_200kHz_min', 'Sv_200kHz_p5', 'Sv_200kHz_p25', 'Sv_200kHz_p50', 'Sv_200kHz_p75', 'Sv_200kHz_p95', 'Sv_200kHz_max', 'Sv_200kHz_std', 'Sv_ref_18kHz', 'Sv_ref_120kHz', 'Sv_ref_200kHz', 'length', 'thickness', 'area', 'perimeter', 'rectangularity', 'compact', 'circularity', 'elongation']
right_feats = sel_feats
k = 10
u = 200

# %%
# co-training with CNN features
co_training_CNN = TrainCoTrainingCNN(pkl_dir, train_dir, threshold, neg_pos_ratio, unlabel_label_ratio, sel_feats, k, u)
co_training_CNN.train_co_training()
# Out:
# 719 1439 2159
# /home/yazh0781/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448265233/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.8867       0.5903        4.2807  1.3718
#       2        0.3115       0.6759        0.7315  1.0474
#       3        0.2825       0.6713        0.8974  1.0327
#       4        0.2875       0.5810        0.8761  1.0284
#       5        0.2567       0.7477        0.7048  1.0365
#       6        0.2617       0.7083        0.6900  1.0308
#       7        0.2169       0.6736        1.2957  1.0338
#       8        0.1962       0.6944        0.6888  1.0426
#       9        0.1740       0.6875        1.2930  1.0468
#      10        0.1434       0.7593        0.5378  1.0352
#      11        0.1352       0.6944        0.8338  1.0541
#      12        0.0981       0.6875        1.0381  1.0392
#      13        0.0776       0.6759        1.9363  1.0362
#      14        0.1355       0.6898        1.3304  1.0372
#      15        0.1361       0.7245        0.9436  1.0383
#      16        0.0960       0.7569        0.6366  1.0526
#      17        0.0534       0.7269        0.8305  1.0541
#      18        0.0364       0.7384        1.2187  1.0425
#      19        0.0422       0.7778        1.1022  1.0373
#      20        0.0296       0.7940        0.7137  1.0405
# Re-initializing module.
# Re-initializing criterion.
# Re-initializing optimizer.
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.
# Re-initializing module.
# Re-initializing criterion.
# Re-initializing optimizer.
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.0281       0.8203        0.7163  2.2419
#       2        0.0666       0.8842        0.3320  2.2410
#       3        0.0221       0.8593        0.3249  2.2406
#       4        0.0072       0.8496        0.3493  2.2392
#       5        0.0032       0.8442        0.3800  2.2421
#       6        0.0014       0.8626        0.3986  2.2432
#       7        0.0006       0.8561        0.4300  2.2419
#       8        0.0002       0.8528        0.4876  2.2428
#       9        0.0001       0.8517        0.4839  2.2427
#      10        0.0001       0.8528        0.4843  2.2323
#      11        0.0001       0.8528        0.4899  2.2419
#      12        0.0001       0.8528        0.4971  2.2319
#      13        0.0001       0.8528        0.5047  2.2441
#      14        0.0001       0.8528        0.5124  2.2454
#      15        0.0001       0.8528        0.5200  2.2441
#      16        0.0001       0.8539        0.5276  2.2445
#      17        0.0000       0.8539        0.5349  2.2447
#      18        0.0000       0.8539        0.5422  2.2445
#      19        0.0000       0.8539        0.5492  2.2471
#      20        0.0000       0.8539        0.5561  2.2511

# %%
# co-training with HC features
co_training_HC = TrainCoTrainingHC(pkl_dir, threshold, neg_pos_ratio, unlabel_label_ratio, left_feats, right_feats, k, u)
co_training_HC.train_co_training()
# Out:
# /home/yazh0781/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 715 1430 2145

# %% [markdown]
# ## Step 2. Validate model
#
# In this step, we'll run saved model on val dataset, check performance.

# %%
from predict_co_training_CNN import PredictCoTrainingCNN
from predict_co_training_HC import PredictCoTrainingHC

# %%
# add parameters
mode = "val"

# %%
# co-training with CNN features

# %%
# co-training with HC features
co_training_HC = PredictCoTrainingHC(pkl_dir, mode, threshold, iou_threshold, left_feats, right_feats)
result_HC = co_training_HC()
# Out:
# 0/238
# sucessfully generate features!
# sucessfully get labels!
# 1/238
# 2/238
# sucessfully generate features!
# sucessfully get labels!
# 3/238
# 4/238
# sucessfully generate features!
# sucessfully get labels!
# 5/238
# 6/238
# sucessfully generate features!
# sucessfully get labels!
# 7/238
# sucessfully generate features!
# sucessfully get labels!
# 8/238
# sucessfully generate features!
# 9/238
# 10/238
# sucessfully generate features!
# sucessfully get labels!
# 11/238
# sucessfully generate features!
# sucessfully get labels!
# 12/238
# sucessfully generate features!
# sucessfully get labels!
# 13/238
# sucessfully generate features!
# sucessfully get labels!
# 14/238
# sucessfully generate features!
# sucessfully get labels!
# 15/238
# sucessfully generate features!
# sucessfully get labels!
# 16/238
# sucessfully generate features!
# sucessfully get labels!
# 17/238
# sucessfully generate features!
# sucessfully get labels!
# 18/238
# sucessfully generate features!
# sucessfully get labels!
# 19/238
# sucessfully generate features!
# sucessfully get labels!
# 20/238
# 21/238
# sucessfully generate features!
# sucessfully get labels!
# 22/238
# sucessfully generate features!
# sucessfully get labels!
# 23/238
# sucessfully generate features!
# sucessfully get labels!
# 24/238
# sucessfully generate features!
# sucessfully get labels!
# 25/238
# sucessfully generate features!
# sucessfully get labels!
# 26/238
# 27/238
# sucessfully generate features!
# sucessfully get labels!
# 28/238
# 29/238
# 30/238
# 31/238
# sucessfully generate features!
# sucessfully get labels!
# 32/238
# sucessfully generate features!
# sucessfully get labels!
# 33/238
# sucessfully generate features!
# sucessfully get labels!
# 34/238
# sucessfully generate features!
# sucessfully get labels!
# 35/238
# sucessfully generate features!
# sucessfully get labels!
# 36/238
# sucessfully generate features!
# sucessfully get labels!
# 37/238
# 38/238
# 39/238
# sucessfully generate features!
# sucessfully get labels!
# 40/238
# sucessfully generate features!
# 41/238
# 42/238
# sucessfully generate features!
# sucessfully get labels!
# 43/238
# sucessfully generate features!
# sucessfully get labels!
# 44/238
# sucessfully generate features!
# sucessfully get labels!
# 45/238
# sucessfully generate features!
# sucessfully get labels!
# 46/238
# 47/238
# 48/238
# sucessfully generate features!
# sucessfully get labels!
# 49/238
# sucessfully generate features!
# 50/238
# sucessfully generate features!
# sucessfully get labels!
# 51/238
# sucessfully generate features!
# sucessfully get labels!
# 52/238
# sucessfully generate features!
# sucessfully get labels!
# 53/238
# sucessfully generate features!
# 54/238
# sucessfully generate features!
# sucessfully get labels!
# 55/238
# sucessfully generate features!
# sucessfully get labels!
# 56/238
# sucessfully generate features!
# sucessfully get labels!
# 57/238
# 58/238
# sucessfully generate features!
# 59/238
# sucessfully generate features!
# sucessfully get labels!
# 60/238
# sucessfully generate features!
# sucessfully get labels!
# 61/238
# sucessfully generate features!
# sucessfully get labels!
# 62/238
# 63/238
# sucessfully generate features!
# 64/238
# sucessfully generate features!
# sucessfully get labels!
# 65/238
# 66/238
# sucessfully generate features!
# 67/238
# sucessfully generate features!
# sucessfully get labels!
# 68/238
# sucessfully generate features!
# sucessfully get labels!
# 69/238
# 70/238
# 71/238
# sucessfully generate features!
# sucessfully get labels!
# 72/238
# sucessfully generate features!
# sucessfully get labels!
# 73/238
# sucessfully generate features!
# sucessfully get labels!
# 74/238
# sucessfully generate features!
# sucessfully get labels!
# 75/238
# 76/238
# sucessfully generate features!
# sucessfully get labels!
# 77/238
# sucessfully generate features!
# 78/238
# sucessfully generate features!
# 79/238
# sucessfully generate features!
# sucessfully get labels!
# 80/238
# sucessfully generate features!
# 81/238
# sucessfully generate features!
# sucessfully get labels!
# 82/238
# sucessfully generate features!
# sucessfully get labels!
# 83/238
# sucessfully generate features!
# sucessfully get labels!
# 84/238
# sucessfully generate features!
# sucessfully get labels!
# 85/238
# sucessfully generate features!
# sucessfully get labels!
# 86/238
# 87/238
# sucessfully generate features!
# sucessfully get labels!
# 88/238
# 89/238
# 90/238
# sucessfully generate features!
# sucessfully get labels!
# 91/238
# 92/238
# sucessfully generate features!
# sucessfully get labels!
# 93/238
# sucessfully generate features!
# 94/238
# 95/238
# sucessfully generate features!
# 96/238
# sucessfully generate features!
# sucessfully get labels!
# 97/238
# sucessfully generate features!
# sucessfully get labels!
# 98/238
# sucessfully generate features!
# sucessfully get labels!
# 99/238
# sucessfully generate features!
# sucessfully get labels!
# 100/238
# 101/238
# sucessfully generate features!
# 102/238
# sucessfully generate features!
# sucessfully get labels!
# 103/238
# sucessfully generate features!
# sucessfully get labels!
# 104/238
# 105/238
# 106/238
# sucessfully generate features!
# sucessfully get labels!
# 107/238
# sucessfully generate features!
# 108/238
# sucessfully generate features!
# sucessfully get labels!
# 109/238
# 110/238
# sucessfully generate features!
# 111/238
# sucessfully generate features!
# sucessfully get labels!
# 112/238
# sucessfully generate features!
# sucessfully get labels!
# 113/238
# sucessfully generate features!
# sucessfully get labels!
# 114/238
# sucessfully generate features!
# sucessfully get labels!
# 115/238
# sucessfully generate features!
# sucessfully get labels!
# 116/238
# 117/238
# sucessfully generate features!
# sucessfully get labels!
# 118/238
# sucessfully generate features!
# sucessfully get labels!
# 119/238
# sucessfully generate features!
# sucessfully get labels!
# 120/238
# 121/238
# 122/238
# sucessfully generate features!
# sucessfully get labels!
# 123/238
# 124/238
# 125/238
# sucessfully generate features!
# sucessfully get labels!
# 126/238
# sucessfully generate features!
# sucessfully get labels!
# 127/238
# sucessfully generate features!
# sucessfully get labels!
# 128/238
# 129/238
# 130/238
# sucessfully generate features!
# 131/238
# sucessfully generate features!
# sucessfully get labels!
# 132/238
# sucessfully generate features!
# sucessfully get labels!
# 133/238
# sucessfully generate features!
# 134/238
# sucessfully generate features!
# sucessfully get labels!
# 135/238
# 136/238
# 137/238
# 138/238
# sucessfully generate features!
# sucessfully get labels!
# 139/238
# 140/238
# sucessfully generate features!
# sucessfully get labels!
# 141/238
# sucessfully generate features!
# sucessfully get labels!
# 142/238
# sucessfully generate features!
# sucessfully get labels!
# 143/238
# sucessfully generate features!
# sucessfully get labels!
# 144/238
# 145/238
# sucessfully generate features!
# sucessfully get labels!
# 146/238
# 147/238
# sucessfully generate features!
# 148/238
# sucessfully generate features!
# sucessfully get labels!
# 149/238
# sucessfully generate features!
# 150/238
# 151/238
# sucessfully generate features!
# sucessfully get labels!
# 152/238
# sucessfully generate features!
# 153/238
# 154/238
# sucessfully generate features!
# sucessfully get labels!
# 155/238
# sucessfully generate features!
# 156/238
# sucessfully generate features!
# sucessfully get labels!
# 157/238
# sucessfully generate features!
# sucessfully get labels!
# 158/238
# sucessfully generate features!
# sucessfully get labels!
# 159/238
# sucessfully generate features!
# sucessfully get labels!
# 160/238
# sucessfully generate features!
# sucessfully get labels!
# 161/238
# sucessfully generate features!
# sucessfully get labels!
# 162/238
# sucessfully generate features!
# sucessfully get labels!
# 163/238
# 164/238
# 165/238
# sucessfully generate features!
# sucessfully get labels!
# 166/238
# 167/238
# sucessfully generate features!
# 168/238
# sucessfully generate features!
# sucessfully get labels!
# 169/238
# 170/238
# 171/238
# sucessfully generate features!
# sucessfully get labels!
# 172/238
# 173/238
# sucessfully generate features!
# sucessfully get labels!
# 174/238
# sucessfully generate features!
# sucessfully get labels!
# 175/238
# sucessfully generate features!
# sucessfully get labels!
# 176/238
# sucessfully generate features!
# sucessfully get labels!
# 177/238
# sucessfully generate features!
# sucessfully get labels!
# 178/238
# sucessfully generate features!
# sucessfully get labels!
# 179/238
# sucessfully generate features!
# sucessfully get labels!
# 180/238
# sucessfully generate features!
# sucessfully get labels!
# 181/238
# sucessfully generate features!
# sucessfully get labels!
# 182/238
# sucessfully generate features!
# sucessfully get labels!
# 183/238
# sucessfully generate features!
# sucessfully get labels!
# 184/238
# sucessfully generate features!
# sucessfully get labels!
# 185/238
# 186/238
# 187/238
# sucessfully generate features!
# sucessfully get labels!
# 188/238
# 189/238
# sucessfully generate features!
# sucessfully get labels!
# 190/238
# sucessfully generate features!
# sucessfully get labels!
# 191/238
# sucessfully generate features!
# 192/238
# sucessfully generate features!
# sucessfully get labels!
# 193/238
# 194/238
# 195/238
# 196/238
# sucessfully generate features!
# 197/238
# sucessfully generate features!
# sucessfully get labels!
# 198/238
# sucessfully generate features!
# 199/238
# sucessfully generate features!
# sucessfully get labels!
# 200/238
# sucessfully generate features!
# sucessfully get labels!
# 201/238
# 202/238
# 203/238
# sucessfully generate features!
# sucessfully get labels!
# 204/238
# sucessfully generate features!
# sucessfully get labels!
# 205/238
# sucessfully generate features!
# sucessfully get labels!
# 206/238
# sucessfully generate features!
# sucessfully get labels!
# 207/238
# 208/238
# sucessfully generate features!
# sucessfully get labels!
# 209/238
# sucessfully generate features!
# sucessfully get labels!
# 210/238
# 211/238
# sucessfully generate features!
# sucessfully get labels!
# 212/238
# sucessfully generate features!
# sucessfully get labels!
# 213/238
# sucessfully generate features!
# 214/238
# sucessfully generate features!
# sucessfully get labels!
# 215/238
# sucessfully generate features!
# sucessfully get labels!
# 216/238
# sucessfully generate features!
# sucessfully get labels!
# 217/238
# sucessfully generate features!
# 218/238
# 219/238
# sucessfully generate features!
# sucessfully get labels!
# 220/238
# sucessfully generate features!
# 221/238
# sucessfully generate features!
# sucessfully get labels!
# 222/238
# sucessfully generate features!
# sucessfully get labels!
# 223/238
# 224/238
# 225/238
# sucessfully generate features!
# sucessfully get labels!
# 226/238
# sucessfully generate features!
# sucessfully get labels!
# 227/238
# sucessfully generate features!
# sucessfully get labels!
# 228/238
# sucessfully generate features!
# sucessfully get labels!
# 229/238
# sucessfully generate features!
# sucessfully get labels!
# 230/238
# sucessfully generate features!
# sucessfully get labels!
# 231/238
# 232/238
# sucessfully generate features!
# 233/238
# sucessfully generate features!
# 234/238
# sucessfully generate features!
# sucessfully get labels!
# 235/238
# sucessfully generate features!
# sucessfully get labels!
# 236/238
# sucessfully generate features!
# sucessfully get labels!
# 237/238

# %%
import pickle
with open(pkl_dir + f"outputs_HC_{threshold}.pkl", "wb") as handle:
    pickle.dump(result_HC, handle)

# %%
from compute_metrics import FinalMetrics
metrics = FinalMetrics(pkl_dir, mode, result_HC, iou_threshold)
final_metrics = metrics()
print(final_metrics)
# Out:
# {'recall_pixel': 0.6492424845093827, 'recall_object': 0.7163461538461539, 'precision_all': 0.9184027777777778, 'precision_labeled': 0.9796954314720813}
